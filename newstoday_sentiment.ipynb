# %% [markdown]
# <a href="https://colab.research.google.com/github/maxkleiner/maXbox4/blob/master/newstoday_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Do you want to read the news today?

# %%
import nltk                                                
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#import wget                                  
import sys                                   
#nltk.download("vader_lexicon") 
#!pip install feedparser             
import feedparser                            
import pandas as pd 
pd.set_option('display.width',500) 
pd.set_option('max_colwidth', 800)                        
import numpy as np                           
print("This first line after Imports")       
                                             
                                             
def GraphViz(node):                                           
    d = Graph(node)                                           
                                                              
    from graphviz import Digraph                              
    dot = Digraph("Graph", strict=False)                      
    dot.format = "png"                                        
                                                              
    def rec(nodes, parent):                                   
        for d in nodes:                                       
            if not isinstance(d, dict):                       
                dot.node(d, shape=d._graphvizshape)           
                dot.edge(d, parent)                           
            else:                                             
                for k in d:                                   
                    dot.node(k._name, shape=k._graphvizshape) 
                    rec(d[k], k)                              
                    dot.edge(k._name, parent._name)           
    for k in d:                                               
        dot.node(k._name, shape=k._graphvizshape)             
        rec(d[k], k)                                          
    return dot                                                
                                                              
                                                              
news_feed=feedparser.parse("http://feeds.bbci.co.uk/news/world/rss.xml")
sid = SentimentIntensityAnalyzer()                                   
descriptions=["very negative","negative","slightly negative", \
         "neutral","slightly positive", "positive","very positive"]  
num_descriptions = len(descriptions)                                 
frontpage = pd.DataFrame()
print(frontpage.info())                                           
output_path = sys.argv[1]                                            
                                                                     
def compound_polarity_descript(compound):                            
   return descriptions[int(((1 + compound) / 2) * num_descriptions)] 
                                                                     
#wget.download(url, out=destination) #, useragent= "maXbox")         
for entry in news_feed.entries:                                      
    ss = sid.polarity_scores(entry.title + "\n" + entry.summary)     
    series = pd.Series(                                              
     [                                                               
        ss["neg"],                                                   
        ss["neu"],                                                   
        ss["pos"],                                                   
        ss["compound"],                                              
        compound_polarity_descript(ss["compound"]),                  
        entry.title,                                                 
        entry.summary                                                
      ],                                                             
      index=[                                                        
        "neg",                                                       
        "neu",                                                       
        "pos",                                                       
        "compound",                                                  
        "human",                                                     
        "title",                                                     
# print(eachItem["name"]," : ", eachItem["percentage_probability"])  
        "summary"                                                    
      ])                                                             
    frontpage=pd.concat([frontpage,series.to_frame().T],ignore_index=True)

print(frontpage.info())                                                                        
alist=[]                                                             
for count,entry in enumerate(news_feed.entries):                     
   alist.append(str(count)+": "+entry.title)                         
                                                                     
finallist = "\n".join(alist)                                         
with open(output_path, "w") as file:                                 
     file.write(str(finallist))                                      
print(finallist)                                                                     
compound_frontpage = frontpage["compound"].mean(skipna = True)       
print("\n")                                                          
print(frontpage)     
print("\n")                                                 
print("News today: "+compound_polarity_descript(compound_frontpage)) 
print("\n") 
print("integrate newsfeed sentiment detector compute ends...")
# Out:
# This first line after Imports
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrameNone
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   neg       24 non-null     object
#  1   neu       24 non-null     object
#  2   pos       24 non-null     object
#  3   compound  24 non-null     object
#  4   human     24 non-null     object
#  5   title     24 non-null     object
#  6   summary   24 non-null     object
# dtypes: object(7)
# memory usage: 1.4+ KB
# None
# 0: Trump supporters planning armed protests ahead of Biden inauguration, FBI warns
# 1: Firms scrap political donations over Capitol riots
# 2: Capitol police officer Eugene Goodman hailed as 'a hero'
# 3: Sriwijaya Air crash: Plane passed inspection last month
# 4: Being a TikTok influencer without the internet
# 5: Kelly Craft: US envoy's 'last-minute' Taiwan visit angers China
# 6: China: Make-up wipes ad pulled over victim-blaming claims
# 7: Diary Sow: Talented Senegal student disappears in France
# 8: India's top court puts controversial farm laws on hold
# 9: Lisa Montgomery: Judge halts execution of only woman on US death row
# 10: Brexit: UK driver has ham sandwiches confiscated at Dutch border
# 11: Irish mother and baby homes report to be published
# 12: Uganda elections 2021: What you need to know
# 13: Brexit leaves Spain's Costa Brits facing dilemmas
# 14: Silencing Trump: How 'big tech' is taking Trumpism offline
# 15: Danke Apartment: The 'broken eggshell' that left young Chinese homeless
# 16: Hindu shrine desecration: Can Pakistan protect its religious minorities?
# 17: Why this female garbage truck driver hopes more women will join her
# 18: Which country has been hit hardest by coronavirus?
# 19: Which Covid vaccine is better? Pfizer v Oxford v Moderna
# 20: Stammering: 'I thought it made me a failure'
# 21: Plastic surgery: Surgeons who target black women and use influencers for promotion
# 22: Snow storms bring deadly chaos to Japan
# 23: ICYMI: A ‘singing’ lake and a lava fountain
#
#
#       neg  ...                                                                                                              summary
# 0   0.224  ...                      Law enforcement officials warn of plans to hold armed protests before Joe Biden's inauguration.
# 1   0.194  ...                 Many companies say they won't donate to Senators who refused to certify President-elect Biden's win.
# 2   0.169  ...                Footage of the riot shows Mr Goodman lure a mob away from the Senate and the lawmakers hiding inside.
# 3   0.105  ...                  Officials said the plane was deemed airworthy in December after it was grounded for several months.
# 4    0.08  ...  Wasil lives in Jammu Kashmir and for more than a year the Indian government has blocked connectivity in the region.
# 5   0.136  ...                         The trip comes as Washington lifts long-standing curbs on official interactions with Taipei.
# 6   0.266  ...               The Chinese ad sparked outrage for allegedly implying that women were to blame for unwanted attention.
# 7   0.084  ...                An investigation is opened into the disappearance of Diary Sow who has not been seen since 4 January.
# 8   0.151  ...                                     Farmers have been camped outside capital Delhi demanding the repeal of the laws.
# 9    0.13  ...                 The judge orders a mental competency hearing to be held - just hours before the scheduled execution.
# 10      0  ...                    Dutch TV films officials confiscating ham sandwiches from UK drivers under new food import rules.
# 11  0.198  ...                        Taoiseach Micheál Martin said the findings of the report are a "shocking and difficult read".
# 12      0  ...                                                       Five things you need to know about Uganda's divisive election.
# 13      0  ...                         British expats in Spain tell the BBC how the new post-Brexit rules have changed their lives.
# 14  0.112  ...                         Within days tech giants have moved to "deplatform" the president and some of his supporters.
# 15  0.231  ...                      The Danke housing controversy has exposed the vulnerability of young workers in China's cities.
# 16  0.195  ...                   The destruction of a sacred shrine by a mob has left Pakistan's Hindu minority feeling vulnerable.
# 17      0  ...             Belinda Janson hopes she won't be the only woman driving garbage trucks in Ipswich, Australia, for long.
# 18      0  ...                                            Key charts and maps explaining how the virus has spread around the world.
# 19      0  ...                                 Three vaccines have been approved in the UK - what are the differences between them?
# 20  0.298  ...                                           Joe Biden will be the first known president with a stammer to take office.
# 21  0.118  ...                 A BBC investigation finds women suffered life-changing conditions after going to Turkey for surgery.
# 22  0.338  ...                Japan is hit by severe snow storms, killing at least eight and bringing some regions to a standstill.
# 23  0.079  ...             From some chilled out phenomena to feeling the heat in our weekly video round up: In Case You Missed It.
#
# [24 rows x 7 columns]
#
#
# News today: slightly negative
#
#
# integrate newsfeed sentiment detector compute ends...

# %% [markdown]
# Examples:
# 0: FBI fears armed protests by Trump supporters ahead of Biden inauguration
# 1: Firms scrap political donations over Capitol riots
# 2: Capitol police officer Eugene Goodman hailed as 'a hero'
# 3: Sriwijaya Air crash: Plane passed inspection last month
# 4: Stammering: 'I thought it made me a failure'

# %% [markdown]
#      neg  ...                                            summary
# 0   0.224  ...  Law enforcement officials warn of plans to hol...
# 1   0.194  ...  Many companies say they won't donate to Senato...
# 2   0.169  ...  Footage of the riot shows Mr Goodman lure a mo...
# 3   0.105  ...  Officials said the plane was deemed airworthy ...
# 4   0.298  ...  Joe Biden will be the first known president wi...
